# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option("display.max_columns" , None)
pd.options.display.max_rows = 10000

# %%
df = pd.read_csv(r'C:\Users\Vatsal\Desktop\projects\Data Sets\Self\zomato-bangalore-restaurants\zomato.csv')
print(df.shape)
df.head()
# Out:
# (51717, 17)
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
new_df = pd.DataFrame(df)

# %%
print(new_df.apply(lambda new_df:len(new_df.unique())))
# Out:
# url                            51717
# address                        11495
# name                            8792
# online_order                       2
# book_table                         2
# rate                              65
# votes                           2328
# phone                          14927
# location                          94
# rest_type                         94
# dish_liked                      5272
# cuisines                        2724
# approx_cost(for two people)       71
# reviews_list                   22513
# menu_item                       9098
# listed_in(type)                    7
# listed_in(city)                   30
# dtype: int64

# %%
new_df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
new_df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
new_df.drop(['url','address','phone', 'location', 'dish_liked','cuisines','reviews_list','menu_item']
            , axis = 1, inplace = True)
print(new_df.shape)
display(new_df.head(5))
# Out:
# (51717, 9)
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#              rest_type approx_cost(for two people) listed_in(type)  \
# 0        Casual Dining                         800          Buffet
# 1        Casual Dining                         800          Buffet
# 2  Cafe, Casual Dining                         800          Buffet
# 3          Quick Bites                         300          Buffet
# 4        Casual Dining                         600          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari
# 2    Banashankari
# 3    Banashankari
# 4    Banashankari

# %%
print(new_df.apply(lambda new_df:len(new_df.unique())))
# Out:
# name                           8792
# online_order                      2
# book_table                        2
# rate                             65
# votes                          2328
# rest_type                        94
# approx_cost(for two people)      71
# listed_in(type)                   7
# listed_in(city)                  30
# dtype: int64

# %%
new_df.isnull().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           7775
# votes                             0
# rest_type                       227
# approx_cost(for two people)     346
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
new_df.dropna(subset=['rest_type','approx_cost(for two people)'], axis=0, inplace=True)

# %% [markdown]
# We dropped missing values of variable name: 'rest_type' and 'approx_cost'because they fell in the 15% cut-off mark for dropping missing row values.
# In this case: 15% of 51717 = 7757.55 or 7757 rows

# %%
new_df.isna().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           7626
# votes                             0
# rest_type                         0
# approx_cost(for two people)       0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
new_df.shape
# Out:
# (51167, 9)

# %%
new_df.dropna(subset=['rate'], axis=0, inplace=True)
print(new_df.shape)
# Out:
# (43541, 9)

# %%
new_df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# rest_type                      0
# approx_cost(for two people)    0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %% [markdown]
# We dropped missing values of variable name: 'rate'because it fell in the 15% cut-off mark for dropping missing row values.
# In this case: 15% of 51167 = 7665.05 or 7665 rows

# %%
new_df.dtypes
# Out:
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# rest_type                      object
# approx_cost(for two people)    object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
#Filter categorical variables and get dataframe will all strings columns names
category_cols = new_df.select_dtypes(include=['object'])
#Print frequency of categories
for col in category_cols:
    #Number of times each value appears in the column
    frequency = new_df[col].value_counts()
    print('\nThis is the frequency distribution for ' + col + ':')
    print(frequency)
# Out:
# This is the frequency distribution for name:
# Cafe Coffee Day                                                                                                                                                    89
# Onesta                                                                                                                                                             85
# Empire Restaurant                                                                                                                                                  71
# Five Star Chicken                                                                                                                                                  68
# Just Bake                                                                                                                                                          68
# ...

# %%
print(new_df.apply(lambda new_df:len(new_df.unique())))
# Out:
# name                           7116
# online_order                      2
# book_table                        2
# rate                             64
# votes                          2323
# rest_type                        87
# approx_cost(for two people)      66
# listed_in(type)                   7
# listed_in(city)                  30
# dtype: int64

# %%
new_df.rate.replace(to_replace=['1.8/5','1.8 /5'], value = '1.5', inplace=True)
new_df.rate.replace(to_replace=['2.0/5','2.1/5','2.2/5','2.3/5','2.4/5',
                               '2.0 /5','2.1 /5','2.2 /5','2.3 /5','2.4 /5'], value = '2' , inplace=True)
new_df.rate.replace(to_replace=['2.5/5','2.6/5','2.7/5','2.8/5','2.9/5',
                                '2.9 /5','2.8 /5','2.7 /5','2.6 /5', '2.5 /5'], value = '2.5' , inplace=True)
new_df.rate.replace(to_replace=['3.0/5','3.1/5','3.2/5','3.3/5','3.4/5',
                               '3.0 /5','3.1 /5','3.2 /5','3.3 /5','3.4 /5'], value = '3' , inplace=True)
new_df.rate.replace(to_replace=['3.5/5','3.6/5','3.7/5','3.8/5','3.9/5',
                                '3.9 /5','3.8 /5','3.7 /5','3.6 /5', '3.5 /5'], value = '3.5' , inplace=True)
new_df.rate.replace(to_replace=['4.0/5','4.1/5','4.2/5','4.3/5','4.4/5',
                               '4.0 /5','4.1 /5','4.2 /5','4.3 /5','4.4 /5'], value = '4' , inplace=True)
new_df.rate.replace(to_replace=['4.5/5','4.6/5','4.7/5','4.8/5','4.9/5',
                                '4.9 /5','4.8 /5','4.7 /5','4.6 /5', '4.5 /5'], value = '4.5' , inplace=True)
new_df.rate.replace(to_replace=['-','NEW'], value = '0', inplace=True)

# %%
new_df['rate'].value_counts()
# Out:
# 3.5    17639
# 4      11057
# 3       9115
# 0       2270
# 2.5     2033
# 4.5     1244
# 2        178
# 1.5        5
# Name: rate, dtype: int64

# %% [markdown]
# ###### Break up of Rate:
# 1. 0 = New restaurants (Unrated)
# 2. 1.5 = Restaurants that got rating above 1.5 and below 2
# 3. 2 = Restaurants that got rating above 2 and below 2.5
# 4. 2.5 = Restaurants that got rating above 2.5 and below 3
# 5. 3 = Restaurants that got rating above 3 and below 3.5
# 6. 3.5 = Restaurants that got rating above 3.5 and below 4
# 7. 4 = Restaurants that got rating above 4 and below 4.5
# 8. 4.5 = Restaurants that got rating above 4.5 and below 5

# %%
colname =[]
for j in new_df.columns[:]:
    if new_df[j].dtype == 'object':
        colname.append(j)
colname
# Out:
# ['name',
#  'online_order',
#  'book_table',
#  'rate',
#  'rest_type',
#  'approx_cost(for two people)',
#  'listed_in(type)',
#  'listed_in(city)']

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

for j in colname:
    new_df[j] = le.fit_transform(new_df[j].astype(str))

# %%
new_df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'rest_type',
#        'approx_cost(for two people)', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
X1 = pd.DataFrame(new_df)
Y1 = pd.DataFrame(new_df['rate'])
print('X1 shape: ', X1.shape)
print('Y1 shape: ',Y1.shape)
# Out:
# X1 shape:  (43541, 9)
# Y1 shape:  (43541, 1)

# %%
X = X1.values[:,:-1]
Y = Y1.values[:,-1]
Y = Y.astype(int)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X)

X = scaler.transform(X)
print(X)
# Out:
# [[-0.24664094  0.73719724  2.40174557 ... -0.83263439  1.24124408
#   -2.40511851]
#  [ 1.04509188  0.73719724 -0.41636384 ... -0.83263439  1.24124408
#   -2.40511851]
#  [ 0.84510033  0.73719724 -0.41636384 ... -1.02361238  1.24124408
#   -2.40511851]
#  ...
#  [-1.3538405  -1.35648908 -0.41636384 ... -1.52015515 -1.7308254
#    2.73899374]
#  [-1.01327519 -1.35648908  2.40174557 ... -1.52015515 -0.72144331
#    2.73899374]
#  [ 1.42381982 -1.35648908 -0.41636384 ... -1.48195956 -1.7308254
#    2.73899374]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.3, random_state = 10)

# %% [markdown]
# ## Logistic Regression:

# %%
#Building the model
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression() # creating the model object
#Fitting the training data in the model
classifier.fit(X_train,Y_train)
Y_pred = classifier.predict(X_test)
#print(list(zip(Y_test,Y_pred)))
#print(classifier.coef_)
#print(classifier.intercept_)

# %%
#Evaluating the model

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm= confusion_matrix (Y_test,Y_pred)
print(cfm)

print("Classification report: ")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model:",acc)
# Out:
# [[ 708    0    0    0    0    0    0]
#  [  10    0   15   26    0    0    0]
#  [   0    0   17  424  180    0    0]
#  [   0    0    0  792 1914    0    0]
#  [   0    0   10    0 5204   48    0]
#  [   0    0    0    0    0 3327    0]
#  [   0    0    0    0    0  301   87]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       708
#            2       0.00      0.00      0.00        51
#            3       0.40      0.03      0.05       621
#            4       0.64      0.29      0.40      2706
#            5       0.71      0.99      0.83      5262
#            6       0.91      1.00      0.95      3327
#            7       1.00      0.22      0.37       388
#
#     accuracy                           0.78     13063
#    macro avg       0.66      0.50      0.51     13063
# weighted avg       0.75      0.78      0.73     13063
#
# Accuracy of the model: 0.7758554696470948

# %% [markdown]
# ## Naive Bayes

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, Y_train)

Y_pred_NB= classifier.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(Y_test, Y_pred_NB))
print(confusion_matrix(Y_test, Y_pred_NB))
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(Y_pred_NB,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       708
#            2       1.00      1.00      1.00        51
#            3       1.00      1.00      1.00       621
#            4       1.00      1.00      1.00      2706
#            5       1.00      1.00      1.00      5262
#            6       1.00      1.00      1.00      3327
#            7       1.00      1.00      1.00       388
#
#     accuracy                           1.00     13063
#    macro avg       1.00      1.00      1.00     13063
# weighted avg       1.00      1.00      1.00     13063
#
# [[ 708    0    0    0    0    0    0]
#  [   0   51    0    0    0    0    0]
#  [   0    0  621    0    0    0    0]
#  [   0    0    0 2706    0    0    0]
#  [   0    0    0    0 5262    0    0]
#  [   0    0    0    0    0 3327    0]
#  [   0    0    0    0    0    0  388]]
# accuracy is 1.0

# %% [markdown]
# ## Decision Tree

# %%
# Decision Tree's
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier()

classifier.fit(X_train, Y_train)

y_pred_DT = classifier.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(Y_test, y_pred_DT))
print(confusion_matrix(Y_test, y_pred_DT))
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred_DT,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       708
#            2       1.00      1.00      1.00        51
#            3       1.00      1.00      1.00       621
#            4       1.00      1.00      1.00      2706
#            5       1.00      1.00      1.00      5262
#            6       1.00      1.00      1.00      3327
#            7       1.00      1.00      1.00       388
#
#     accuracy                           1.00     13063
#    macro avg       1.00      1.00      1.00     13063
# weighted avg       1.00      1.00      1.00     13063
#
# [[ 708    0    0    0    0    0    0]
#  [   0   51    0    0    0    0    0]
#  [   0    0  621    0    0    0    0]
#  [   0    0    0 2706    0    0    0]
#  [   0    0    0    0 5262    0    0]
#  [   0    0    0    0    0 3327    0]
#  [   0    0    0    0    0    0  388]]
# accuracy is 1.0
